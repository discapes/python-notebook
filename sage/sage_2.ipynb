# %%
reset()
,var x y z a b c
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# %display latex

# %%
(plot(2^x,-5,0, fill=True)
+ plot(2^x, 0,1, fill=True, fillcolor="green") 
+ plot(2^x, 1, 3, fill=True, fillcolor="orange")
+ text("negative: under 1", (-1.5, 1))
+ text("0-1: under N", (0.8, 3))
+ plot(2,-5,3)
+ point((0,1), size=30)
+ point((1,2), size=30)
)
# Out:
# Graphics object consisting of 11 graphics primitives

# %%
(plot(0.5^x,-3,0, fill=True)
+ plot(0.5^x, 0,1, fill=True, fillcolor="green") 
+ plot(0.5^x, 1, 5, fill=True, fillcolor="orange")
+ text("negative: under 1", (-1.5, 1))
+ text("0-1: under N", (0.8, 3))
+ plot(2,-3,5)
+ point((0,1), size=30)
+ point((-1,2), size=30)
)
# Out:
# Graphics object consisting of 11 graphics primitives

# %%
25*(x^3+x^2)/5/(x^2-1)
_.simplify()
_.simplify_full()
# Out:
# 5*(x^3 + x^2)/(x^2 - 1)
# 5*(x^3 + x^2)/(x^2 - 1)
# 5*x^2/(x - 1)
